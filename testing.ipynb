# %%
from generate_synthetic_data import generate_synthetic_committee_data

df = generate_synthetic_committee_data()
df.head()
# Out:
#    label  vote_Normal  vote_Normal Co-Op  gender
# 0      1            0                  1  Female
# 1      1            1                  1    Male
# 2      1            0                  1    Male
# 3      0            0                  0  Female
# 4      0            0                  0    Male
